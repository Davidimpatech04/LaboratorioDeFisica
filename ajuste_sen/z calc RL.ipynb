# %%
import ajuste_sen as aj

# %%
path = "datas/RL10.csv"
path_s = "results/RL/RL 38006/z RL - 38006.txt"
path_graph = "results/RL/RL 38006/graph.png"
path_regres = "results/RL/RL 38006/regres.png"
arg_1 = [2,200,3,0]
arg_2 = [2,200,3,0]
arg_vr = [2,200,2,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2, argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL20.csv"
path_s = "results/RL/RL 76012/z RL - 76012.txt"
path_graph = "results/RL/RL 76012/graph.png"
path_regres = "results/RL/RL 76012/regres.png"
arg_1 = [2,400,3,0]
arg_2 = [2,400,3,0]
arg_vr = [2,400,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL30.csv"
path_s = "results/RL/RL 152024/z RL - 152024.txt"
path_graph = "results/RL/RL 152024/graph.png"
path_regres = "results/RL/RL 152024/regres.png"
arg_1 = [2,1000,3,0]
arg_2 = [2,1000,3,0]
arg_vr = [2,1000,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL40.csv"
path_s = "results/RL/RL 304048/z RL - 304048.txt"
path_graph = "results/RL/RL 304048/graph.png"
path_regres = "results/RL/RL 304048/regres.png"
arg_1 = [2,2000,3,0]
arg_2 = [2,2000,3,0]
arg_vr = [2,2000,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL50.csv"
path_s = "results/RL/RL 608096/z RL - 608096.txt"
path_graph = "results/RL/RL 608096/graph.png"
path_regres = "results/RL/RL 608096/regres.png"
arg_1 = [2,4000,3,0]
arg_2 = [2,4000,3,0]
arg_vr = [2,4000,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr= arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL-20.csv"
path_s = "results/RL/RL 19003/z RL - 19003.txt"
path_graph = "results/RL/RL 19003/graph.png"
path_regres = "results/RL/RL 19003/regres.png"
arg_1 = [2,100,3,0]
arg_2 = [2,100,3,0]
arg_vl = [4,100,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vl)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL-30.csv"
path_s = "results/RL/RL 9501,5/z RL - 9.501,5.txt"
path_graph = "results/RL/RL 9501,5/graph.png"
path_regres = "results/RL/RL 9501,5/regres.png"
arg_1 = [2,50,3,0]
arg_2 = [4,55,3,0]
arg_vr = [4,55,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL-40.csv"
path_s = "results/RL/RL 4750,75/z RL - 4.750,75.txt"
path_graph = "results/RL/RL 4750,75/graph.png"
path_regres = "results/RL/RL 4750,75/regres.png"
arg_1 = [2,30,3,0]
arg_2 = [4,35,3,0]
arg_vr = [4,35,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr= arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RL-50.csv"
path_s = "results/RL/RL 2375,375/z RL - 2.375,375.txt"
path_graph = "results/RL/RL 2375,375/graph.png"
path_regres = "results/RL/RL 2375,375/regres.png"
arg_1 = [2,15,3,0]
arg_2 = [4,17,3,0]
arg_vr = [4,17,3,0]
aj.save_datas(path,path_s,path_graph,path_regres,arg_1,arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)
