# %%
import ajuste_sen as aj
import altair as alt

# %%
path = "datas/RC10.csv"
path_s = "results/RC/RC 740/z RC - 740.txt"
arg_1 = [3,4,1,-2]
arg_2 = [3,4,2,-2]
arg_vr = [3,4,1,-2]
path_graph = "results/RC/RC 740/graph.png"
path_regres = "results/RC/RC 740/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww= arg_1 , argwww=arg_2, argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC-20.csv"
path_s = "results/RC/RC 370/z RC - 370.txt"
arg_1 = [4,2,2,-100]
arg_2 = [4,2,2,-100]
arg_vr = [3,2,3,0]
path_graph = "results/RC/RC 370/graph.png"
path_regres = "results/RC/RC 370/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC20.csv"
path_s = "results/RC/RC 1480/z RC - 1480.txt"
arg_1 = [2,10,3,10]
arg_2 = [4,10,3,10]
arg_vr = [2,10,3,-1]
path_graph = "results/RC/RC 1480/graph.png"
path_regres = "results/RC/RC 1480/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC30.csv"
path_s = "results/RC/RC 2960/z RC - 2960.txt"
arg_1 = [2,20,3,10]
arg_2 = [4,20,3,10]
arg_vr = [4,20,3,0]
path_graph = "results/RC/RC 2960/graph.png"
path_regres = "results/RC/RC 2960/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC40.csv"
path_s = "results/RC/RC 5920/z RC - 5920.txt"
arg_1 = [1,40,3,10]
arg_2 = [4,40,3,10]
arg_vr = [4,40,3,0]
path_graph = "results/RC/RC 5920/graph.png"
path_regres = "results/RC/RC 5920/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC-30.csv"
path_s = "results/RC/RC 185/z RC - 185.txt"
arg_1 = [4,1,3,-100]
arg_2 = [4,1,3,-100]
arg_vr = [0.8,1,3,-1]
path_graph = "results/RC/RC 185/graph.png"
path_regres = "results/RC/RC 185/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC-40.csv"
path_s = "results/RC/RC 92,5/z RC - 92,5.txt"
arg_1 = [4,0.5,3,-100]
arg_2 = [4,0.5,3,-100]
arg_vr = [4,0.5,3,0]
path_graph = "results/RC/RC 92,5/graph.png"
path_regres = "results/RC/RC 92,5/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC-50.csv"
path_s = "results/RC/RC 46,25/z RC - 46,25.txt"
arg_1 = [4,0.3,3,-100]
arg_2 = [4,0.3,3,-100]
arg_vr = [2,0.3,3,0]
path_graph = "results/RC/RC 46,25/graph.png"
path_regres = "results/RC/RC 46,25/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RC50.csv"
path_s = "results/RC/RC 11840/z RC - 11840.txt"
arg_1 = [0.02,70,3,2.5]
arg_2 = [1,70,3,2.5]
arg_vr = [2,70,3,0]
path_graph = "results/RC/RC 11840/graph.png"
path_regres = "results/RC/RC 11840/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)
