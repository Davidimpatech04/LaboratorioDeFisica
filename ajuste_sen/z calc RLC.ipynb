# %%
import ajuste_sen as aj

# %%
path = "datas/RLC10.csv"
path_s = "results/RLC/RLC 3600/z RLC - 3600.txt"
arg_1 = [3,20,3,3]
arg_2 = [5,20,3,3]
arg_vr = [5,20,3,3]
path_graph = "results/RLC/RLC 3600/graph.png"
path_regres = "results/RLC/RLC 3600/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC20.csv"
arg_1 = [3,40,3,3]
arg_2 = [5,40,3,3]
arg_vr = [5,40,3,3]
path_s = "results/RLC/RLC 7200/z RLC - 7200.txt"
path_graph = "results/RLC/RLC 7200/graph.png"
path_regres = "results/RLC/RLC 7200/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC30.csv"
arg_1 = [3,80,3,3]
arg_2 = [5,80,3,3]
arg_vr = [5,80,3,3]
path_s = "results/RLC/RLC 14400/z RLC - 14400.txt"
path_graph = "results/RLC/RLC 14400/graph.png"
path_regres = "results/RLC/RLC 14400/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC40.csv"
arg_1 = [3,160,3,3]
arg_2 = [5,160,3,3]
arg_vr = [5,160,3,3]
path_s = "results/RLC/RLC 28800/z RLC - 28800.txt"
path_graph = "results/RLC/RLC 28800/graph.png"
path_regres = "results/RLC/RLC 28800/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC50.csv"
path_s = "z RLC - 57600.txt"
arg_1 = [3,320,3,3]
arg_2 = [5,320,3,3]
arg_vr = [5,320,3,3]
path_s = "results/RLC/RLC 57600/z RLC - 57600.txt"
path_graph = "results/RLC/RLC 57600/graph.png"
path_regres = "results/RLC/RLC 57600/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC-20.csv"
path_s = "z RLC - 1800.txt"
arg_1 = [3,10,3,3]
arg_2 = [5,10,3,3]
arg_vr = [5,10,3,3]
path_s = "results/RLC/RLC 1800/z RLC - 1800.txt"
path_graph = "results/RLC/RLC 1800/graph.png"
path_regres = "results/RLC/RLC 1800/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC-30.csv"
path_s = "z RLC - 900.txt"
arg_1 = [3,5,3,3]
arg_2 = [5,5,3,3]
arg_vr = [5,5,3,3]
path_s = "results/RLC/RLC 900/z RLC - 900.txt"
path_graph = "results/RLC/RLC 900/graph.png"
path_regres = "results/RLC/RLC 900/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC-40.csv"
path_s = "z RLC - 450.txt"
arg_1 = [3,2.5,3,3]
arg_2 = [5,2.5,3,3]
arg_vr = [5,2.5,3,3]
path_s = "results/RLC/RLC 450/z RLC - 450.txt"
path_graph = "results/RLC/RLC 450/graph.png"
path_regres = "results/RLC/RLC 450/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)

# %%
path = "datas/RLC-50.csv"
path_s = "z RLC - 225.txt"
arg_1 = [2.5,1.5,5,3]
arg_2 = [2.5,1.5,5,3]
arg_vr = [2.5,1.5,5,3]
path_s = "results/RLC/RLC 225/z RLC - 225.txt"
path_graph = "results/RLC/RLC 225/graph.png"
path_regres = "results/RLC/RLC 225/regres.png"
aj.save_datas(path,path_s,path_graph,path_regres,argww=arg_1,argwww=arg_2,argvr=arg_vr)
# Out:
# alt.LayerChart(...)
# alt.HConcatChart(...)
