# %%
import altair as alt
import pandas as pd
import numpy as np
import scipy as scp
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
data = pd.read_csv("lll.csv")
xdata = np.arange(0,12521)
data["a"] = xdata
data
data = data.loc[data["erro"] < 9]

# %%
alt.Chart(data).mark_tick(color = "blueviolet").encode(
    alt.X("a"),
    alt.Y("erro"),
    tooltip = ["erro"]
).properties(
    width = 1000
)
# Out:
# alt.Chart(...)

# %% [markdown]
# henriquil 1 ->
#
# KP - 125
#
# KI - 1
#
# KD - 0
#
# henriquil 2 ->
#
# KP - 125
#
# KI - 1
#
# KD - 1
